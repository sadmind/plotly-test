# %%
import plotly.plotly as py
import plotly.graph_objs as go

# %%
years=range(1970,2019)

# %%
trace_boy = go.Scatter(
    y = [
        203168,
        195938,
        188132,
        189565,
        189579,
        189266,
        218655,
        203840,
        212017,
        218532,
        213205,
        213948,
        209457,
        198240,
        192034,
        178336,
        160226,
        163331,
        177687,
        164147,
        176029,
        168865,
        168488,
        169486,
        168444,
        171118,
        169484,
        170047,
        141462,
        148042,
        159726,
        135596,
        129537,
        118984,
        113639,
        107378,
        106936,
        106898,
        103937,
        99492,
        87213,
        101943,
        118848,
        103120,
        108817,
        111041,
        108133,
        100477,
        93367
    ],
    x = years,
    marker = {'color': 'blue', 'symbol': 'circle'},
    mode = 'lines+markers',
    name = 'boy'
)
trace_girl = go.Scatter(
    y = [
        190847,
        184486,
        177617,
        177377,
        178244,
        178381,
        204701,
        191956,
        197186,
        203986,
        200676,
        200121,
        195806,
        185199,
        178974,
        167872,
        149004,
        150693,
        164344,
        151152,
        159589,
        153067,
        153144,
        156127,
        154494,
        158463,
        156061,
        155955,
        129988,
        135619,
        145586,
        124758,
        117993,
        108086,
        102780,
        98476,
        97523,
        97516,
        94796,
        91818,
        79673,
        94684,
        110633,
        95993,
        101566,
        102557,
        100307,
        93367,
        87725
    ],
    x = years,
    marker = {'color': 'red', 'symbol': 'diamond'},
    mode = 'lines+markers',
    name = 'girl'
)
data = [trace_boy, trace_girl]

layout = dict(title = '歷年男女出生人數',
              yaxis = dict(title = '人數'),
              xaxis = dict(title = '年份'),
             )

fig = dict(data=data, layout=layout)
py.iplot(fig, filename='years-of-born')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~SimonLiao/14.embed" height="525px" width="100%"></iframe>
